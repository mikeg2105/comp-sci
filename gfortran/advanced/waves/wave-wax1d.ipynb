# %%
from os import *


#import numpy as np
#application which reads columnar data from file
#using matplotlib,scipy and numpy
import numpy as np
from numpy import *
import scipy.io
from scipy import special
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import struct
import matplotlib.animation as animation
from IPython.display import HTML
# %matplotlib inline  

#load data from text file
t1a=np.loadtxt('results.txt')

# %%
asz=t1a.size

print(asz)

shap=t1a.shape

print(shap)
# Out:
# 43624
# (287, 152)

# %%
x=t1a[0,:]

# %%
plt.plot(x)

# %%
plt.plot(x,t1a[283,:])

# %%
#first read the array of densities
ii=1
Nt=shap[0]-2  #number of time steps
print(Nt)
# Out:
# 285

# %%
fig, ax = plt.subplots()
ii=2
Nvar=Nt

print(ii)

line, =ax.plot(t1a[ii,:], color='green')
# Out:
# 2

# %%
def updatefig(*args):
    global ii
    ii += 1
    if ii >= Nvar: return line,
    #im.set_array(lnrho[ii][:][:])
    line.set_ydata(t1a[ii,:])  # update the data.
    return line,




ani = animation.FuncAnimation(fig, updatefig, interval=500, frames=Nt)

# %%
HTML(ani.to_html5_video())
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
